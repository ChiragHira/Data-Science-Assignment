# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Ans.Matplotlib is a popular 2D plotting library for Python that provides a variety of tools for creating static, animated, and interactive visualizations in Python.Matplotlib is widely used in fields such as data science, machine learning, finance, biology, and more.
#
#
#
#
# Line Plot:
#
# Scatter Plot:
#
# Bar Plot:
#
#
# Histogram:
#
#
# Pie Chart:

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

plt.xlabel = 'X values'
plt.ylabel = 'Y values'
plt.scatter(x,y)

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %%
x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2,2,1)
plt.plot(x1,y1)

x2 = np.array([0, 1, 2, 3, 4, 5]) 
y2 = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(2,2,2)
plt.plot(x2,y2)

x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3 = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2,2,3)
plt.plot(x3,y3)

x4 = np.array([0, 1, 2, 3, 4, 5]) 
y4 = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,2,4)
plt.plot(x4,y4)

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# In Matplotlib, a bar plot is a type of chart that presents categorical data with rectangular bars. Each bar's length or height is proportional to the values it represents. Bar plots are useful for comparing the quantities of different categories.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

plt.subplot(1,2,1)
plt.boxplot(box1)

plt.subplot(1,2,2)
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24000097f40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x240000c4340>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24000097df0>],
#  'medians': [<matplotlib.lines.Line2D at 0x240000c4880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x240000c4b20>],
#  'means': []}
