# %% [markdown]
# Q1. Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a
# scatter plot for age and fare columns in the titanic dataset.

# %%
import plotly.graph_objects as go
import pandas as pd

Titanic = pd.read_csv("titanic.csv")
Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
Fig = go.Figure()
Fig.add_trace(go.Scatter(x=Titanic.Age,y=Titanic.Fare,mode='markers'))

# %% [markdown]
# Q2. Using the tips dataset in the Plotly library, plot a box plot using Plotly express.

# %% [markdown]
# Q3. Using the tips dataset in the Plotly library, Plot a histogram for x= "sex" and y="total_bill" column in
# the tips dataset. Also, use the "smoker" column with the pattern_shape parameter and the "day"
# column with the color parameter.

# %%
import plotly.express as px

Tip = pd.read_csv('Tips.csv')
fig = px.histogram(Tip, x ='sex',y='total_bill',color='day',pattern_shape='smoker')
fig.show()

# %% [markdown]
# Q4. Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the "species" column for
# the color parameter.

# %%
Iris = px.data.iris()
Iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 145           3
# 146           3
# 147           3
# 148           3
# 149           3
#
# [150 rows x 6 columns]

# %%
fig = px.scatter_matrix(Iris,
    dimensions=["sepal_length", "sepal_width", "petal_length", "petal_width"],
    color="species")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Data Science Assignment\ploty_ass.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20Science%20Assignment/ploty_ass.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> fig = px.scatter_matrix(Iris,
#       <a href='vscode-notebook-cell:/d%3A/Data%20Science%20Assignment/ploty_ass.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a>     dimensions=["sepal_length", "sepal_width", "petal_length", "petal_width"],
#       <a href='vscode-notebook-cell:/d%3A/Data%20Science%20Assignment/ploty_ass.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a>     color="species")
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_chart_types.py:1392, in scatter_matrix(data_frame, dimensions, color, symbol, size, hover_name, hover_data, custom_data, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, title, template, width, height)
#    1361 def scatter_matrix(
#    1362     data_frame=None,
#    1363     dimensions=None,
#    (...)
#    1384     height=None,
#    1385 ) -> go.Figure:
#    1386     """
#    1387     In a scatter plot matrix (or SPLOM), each row of `data_frame` is
#    1388     represented by a multiple symbol marks, one in each cell of a grid of
#    1389     2D scatter plots, which plot each pair of `dimensions` against each
#    1390     other.
#    1391     """
# -> 1392     return make_figure(
#    1393         args=locals(), constructor=go.Splom, layout_patch=dict(dragmode="select")
#    1394     )
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:2167, in make_figure(args, constructor, trace_patch, layout_patch)
#    2164     elif args["ecdfnorm"] == "percent":
#    2165         group[var] = 100.0 * group[var] / group_sum
# -> 2167 patch, fit_results = make_trace_kwargs(
#    2168     args, trace_spec, group, mapping_labels.copy(), sizeref
#    2169 )
#    2170 trace.update(patch)
#    2171 if fit_results is not None:
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:281, in make_trace_kwargs(args, trace_spec, trace_data, mapping_labels, sizeref)
#     277 attr_label = get_decorated_label(args, attr_value, attr_name)
#     278 if attr_name == "dimensions":
#     279     dims = [
#     280         (name, column)
# --> 281         for (name, column) in trace_data.iteritems()
#     282         if ((not attr_value) or (name in attr_value))
#     283         and (
#     284             trace_spec.constructor != go.Parcoords
#     285             or _is_continuous(args["data_frame"], name)
#     286         )
#     287         and (
#     288             trace_spec.constructor != go.Parcats
#     289             or (attr_value is not None and name in attr_value)
#     290             or len(args["data_frame"][name].unique())
#     291             <= args["dimensions_max_cardinality"]
#     292         )
#     293     ]
#     294     trace_patch["dimensions"] = [
#     295         dict(label=get_label(args, name), values=column)
#     296         for (name, column) in dims
#     297     ]
#     298     if trace_spec.constructor == go.Splom:
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'iteritems'

# %% [markdown]
# Q5. What is Distplot? Using Plotly express, plot a distplot.
